# %%
# initial imports
import pandas as pd
import numpy as np
from pathlib import Path
import panel as pn
from panel.interact import interact
import plotly.express as px
pn.extension("plotly")

# %%
sales = pd.read_csv(
    Path("csv1.csv"),
    infer_datetime_format=True,
    parse_dates=True,
    index_col="close",
).dropna()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-5cbc74ab83d7> in <module>
#       3     infer_datetime_format=True,
#       4     parse_dates=True,
# ----> 5     index_col="close",
#       6 ).dropna()
#
# ~/opt/anaconda3/envs/pyvizenv/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# ~/opt/anaconda3/envs/pyvizenv/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     427
#     428     # Create the parser.
# --> 429     parser = TextFileReader(filepath_or_buffer, **kwds)
#     430
#     431     if chunksize or iterator:
#
# ~/opt/anaconda3/envs/pyvizenv/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options['has_index_names'] = kwds['has_index_names']
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~/opt/anaconda3/envs/pyvizenv/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1120     def _make_engine(self, engine='c'):
#    1121         if engine == 'c':
# -> 1122             self._engine = CParserWrapper(self.f, **self.options)
#    1123         else:
#    1124             if engine == 'python':
#
# ~/opt/anaconda3/envs/pyvizenv/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1902                 _validate_usecols_names(usecols, self.names)
#    1903
# -> 1904         self._set_noconvert_columns()
#    1905
#    1906         self.orig_names = self.names
#
# ~/opt/anaconda3/envs/pyvizenv/lib/python3.7/site-packages/pandas/io/parsers.py in _set_noconvert_columns(self)
#    1984             if isinstance(self.index_col, list):
#    1985                 for k in self.index_col:
# -> 1986                     _set(k)
#    1987             elif self.index_col is not None:
#    1988                 _set(self.index_col)
#
# ~/opt/anaconda3/envs/pyvizenv/lib/python3.7/site-packages/pandas/io/parsers.py in _set(x)
#    1961
#    1962             if not is_integer(x):
# -> 1963                 x = names.index(x)
#    1964
#    1965             self._reader.set_noconvert(x)
#
# ValueError: 'close' is not in list
